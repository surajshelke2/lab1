# %%
from scipy import misc, ndimage
import imageio
import matplotlib.pyplot as plt


face_image = misc.face()


imageio.imwrite('face.png', face_image)


plt.imshow(face_image)
plt.title('Original Face Image')
plt.axis('off')  # Turn off axis labels
plt.show()
# Out:
# <ipython-input-8-c4ed8ed54f87>:6: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face_image = misc.face()

# %%
face = misc.face(gray=False)
print(face.mean(),face.max(),face.min())
# Out:
# <ipython-input-10-218b1142850e>:1: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray=False)
# 110.16274388631184 255 0

# %%
face = misc.face(gray=True)
lx,ly=face.shape

crop_face = face[lx // 4:-lx // 4, ly // 4:-ly // 4]

plt.imshow(crop_face)
# Out:
# <ipython-input-21-0c681649c2e8>:1: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = misc.face(gray=True)

# %%
import numpy as np
flip_up_face = np.flipud(face)
plt.imshow(flip_up_face)

# %%
rotate_face = ndimage.rotate(face,45)
plt.imshow(rotate_face)

# %%
blurred = ndimage.gaussian_filter(face,sigma=13)
plt.imshow(blurred)

# %%
from scipy import constants
constants.pi
# Out:
# 1000.0

# %%
constants.kilo
# Out:
# 3600.0

# %%
constants.hour
# Out:
# 3600.0

# %%
constants.day
# Out:
# 86400.0

# %%
constants.week
# Out:
# 604800.0

# %%
constants.year
# Out:
# 31536000.0

# %% [markdown]
# # import scipy as sp

# %%
from scipy import special

# %%
#factorial
special.factorial(5)
# Out:
# 120.0

# %%
#permutation
special.perm(5,2)
# Out:
# 20.0

# %%
#combination
special.comb(5,2)
# Out:
# 10.0

# %%
#
special.binom(5,2)
# Out:
# 10.0

# %%
#exponential
from scipy.stats import expon
expon.pdf(2,scale=1/2)
# Out:
# 0.03663127777746836

# %%
from scipy.stats import norm
norm.cdf(19.5)
# Out:
# 1.0

# %%
from scipy.optimize import curve_fit
def fun(x,a,b):return x*a-b
parmas , covarience = curve_fit(fun, [1,2,3,4],[7,8,9,10])
print(parmas)
# Out:
# [ 1. -6.]

# %%
print(covarience)
# Out:
# [[0. 0.]
#  [0. 0.]]

# %%
from scipy.interpolate import CubicSpline
x=[1,2,3,4,5,6]
y=[1,2,4,5,6,7]
ans =CubicSpline(x,y)
ans

# %%
from scipy.interpolate import interp1d
interp1dx(x,y,kind="linear")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-62aa59cca73c> in <cell line: 2>()
#       1 from scipy.interpolate import interp1d
# ----> 2 interp1dx(x,y,kind="linear")
#
# NameError: name 'interp1dx' is not defined
